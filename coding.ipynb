# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data_Negara_HELP.csv', na_values=['na', '-'])
df
# Out:
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9        1610
# 1                Albania           16.6    28.0       6.55   48.6        9930
# 2                Algeria           27.3    38.4       4.17   31.4       12900
# 3                 Angola          119.0    62.3       2.85   42.9        5900
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7        2950
# 163            Venezuela           17.1    28.5       4.91   17.6       16500
# 164              Vietnam           23.3    72.0       6.84   80.2        4490
# 165                Yemen           56.3    30.0       5.18   34.4        4480
# 166               Zambia           83.1    37.0       5.89   30.9        3280
#
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (167, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Negara            167 non-null    object
#  1   Kematian_anak     167 non-null    float64
#  2   Ekspor            167 non-null    float64
#  3   Kesehatan         167 non-null    float64
#  4   Impor             167 non-null    float64
#  5   Pendapatan        167 non-null    int64
#  6   Inflasi           167 non-null    float64
#  7   Harapan_hidup     167 non-null    float64
#  8   Jumlah_fertiliti  167 non-null    float64
#  9   GDPperkapita      167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB
# None

# %%
df.describe()
# Out:
#        Kematian_anak      Ekspor   Kesehatan       Impor     Pendapatan  \
# count     167.000000  167.000000  167.000000  167.000000     167.000000
# mean       38.270060   41.108976    6.815689   46.890215   17144.688623
# std        40.328931   27.412010    2.746837   24.209589   19278.067698
# min         2.600000    0.109000    1.810000    0.065900     609.000000
# 25%         8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%        19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%        62.100000   51.350000    8.600000   58.750000   22800.000000
# max       208.000000  200.000000   17.900000  174.000000  125000.000000
#
#           Inflasi  Harapan_hidup  Jumlah_fertiliti   GDPperkapita
# count  167.000000     167.000000        167.000000     167.000000
# mean     7.781832      70.555689          2.947964   12964.155689
# std     10.570704       8.893172          1.513848   18328.704809
# ...

# %%
df.isnull().sum()
# Out:
# Negara              0
# Kematian_anak       0
# Ekspor              0
# Kesehatan           0
# Impor               0
# Pendapatan          0
# Inflasi             0
# Harapan_hidup       0
# Jumlah_fertiliti    0
# GDPperkapita        0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# #### Univariate analysis

# %%
plt.figure(figsize=(16,12))

for i in enumerate(df.describe().columns):
  plt.subplot(3,3, i[0]+1)
  sns.distplot(df[i[1]])
plt.show()

# %%
sns.pairplot(df,diag_kind='hist')

# %%
plt.figure(figsize=(14,45))
sns.set_style('whitegrid')
plt.subplot(10,1,1)
sns.lineplot(df.Kematian_anak, df.Pendapatan)
sns.regplot(x="Kematian_anak", y="Pendapatan", data=df)
plt.title('Pendapatan VS Kematian Anak')

plt.subplot(10,1,2)
sns.lineplot(df.Kematian_anak, df.Harapan_hidup)
sns.regplot(x="Kematian_anak", y="Harapan_hidup", data=df)
plt.title('Kematian_anak VS Harapan Hidup')

plt.subplot(10,1,3)
sns.lineplot(df.Kematian_anak, df.Jumlah_fertiliti)
sns.regplot(x="Kematian_anak", y="Jumlah_fertiliti", data=df)
plt.title('Kematian Anak VS Jumlah Fertiliti')

plt.subplot(10,1,4)
sns.lineplot(df.Ekspor, df.Impor)
sns.regplot(x="Ekspor", y="Impor", data=df)
plt.title('Ekspor VS Impor')

plt.subplot(10,1,5)
sns.lineplot(df.Ekspor, df.Pendapatan)
sns.regplot(x="Ekspor", y="Pendapatan", data=df)
plt.title('Ekspor VS Pendapatan')

plt.subplot(10,1,6)
sns.lineplot(df.Harapan_hidup, df.Pendapatan)
sns.regplot(x="Harapan_hidup", y="Pendapatan", data=df)
plt.title('Harapan Hidup VS Pendapatan')

plt.subplot(10,1,7)
sns.lineplot(df.Harapan_hidup, df.Pendapatan)
sns.regplot(x="Harapan_hidup", y="Pendapatan", data=df)
plt.title('Harapan Hidup VS Pendapatan')

plt.subplot(10,1,8)
sns.lineplot(df.GDPperkapita, df.Pendapatan)
sns.regplot(x="GDPperkapita", y="Pendapatan", data=df)
plt.title('GDPperkapita VS Pendapatan')

plt.subplot(10,1,9)
sns.lineplot(df.GDPperkapita, df.Harapan_hidup)
sns.regplot(x="GDPperkapita", y="Harapan_hidup", data=df)
plt.title('GDPperkapita VS Harapan_hidup')

plt.subplot(10,1,10)
sns.lineplot(df.Jumlah_fertiliti, df.Harapan_hidup)
sns.regplot(x="Jumlah_fertiliti", y="Harapan_hidup", data=df)
plt.title('Jumlah Fertiliti VS Harapan_hidup')


plt.tight_layout()
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2g');

# %%
plt.figure(figsize=(16,12))

for i in enumerate(df.describe().columns):
  plt.subplot(3,3, i[0]+1)
  sns.boxplot(df[i[1]])
plt.show()

# %%
#Q1 = df.quantile(0.25)
#Q3 = df.quantile(0.75)
#IQR  = Q3-Q1
#df2 = df[(df>(Q1-(1.5*IQR))) & (df<(Q3+(1.5*IQR)))]
#print(df2.isnull().sum())
df2 = df.drop(columns=['Negara','Inflasi','Kesehatan'])
#display(df2)
#df2.dropna(axis=0, inplace=True)
#print(df2.isnull().sum())

# %%
plt.figure(figsize=(16,12))

for i in enumerate(df2.columns):
  plt.subplot(3,3, i[0]+1)
  sns.boxplot(df2[i[1]])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
df_std1 = sc.fit_transform(df2[['Kematian_anak','Jumlah_fertiliti']].astype(float))
df_std2 = sc.fit_transform(df2[['Kematian_anak','Harapan_hidup']].astype(float))
df_std3 = sc.fit_transform(df2[['Kematian_anak','Pendapatan']].astype(float))
df_std4 = sc.fit_transform(df2[['Ekspor','Impor']].astype(float))
df_std5 = sc.fit_transform(df2[['Ekspor','Pendapatan']].astype(float))
df_std6 = sc.fit_transform(df2[['Pendapatan','Jumlah_fertiliti']].astype(float))
df_std7 = sc.fit_transform(df2[['Pendapatan','Harapan_hidup']].astype(float))
df_std8 = sc.fit_transform(df2[['Pendapatan','GDPperkapita']].astype(float))
df_std9 = sc.fit_transform(df2[['Jumlah_fertiliti','Harapan_hidup']].astype(float))
df_std10 = sc.fit_transform(df2[['GDPperkapita','Harapan_hidup']].astype(float))
df_std = sc.fit_transform(df2.astype(float))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
wcss = []
for i in range(1,11):
    kmeans1 = KMeans(n_clusters=i, init='k-means++', random_state=3)
    kmeans1.fit(df_std)
    wcss.append(kmeans1.inertia_)

plt.plot(range(1,11), wcss)
plt.title('Elbow method')
plt.xlabel('n_clusters')
plt.ylabel('wcss')

plt.show()

# %%
aa=4
b=['blue','red','green','pink']
c=['Kematian_anak','Jumlah_fertiliti']
kmeans1 = KMeans(n_clusters = aa, random_state=49).fit(df_std1)#45
labels1 = kmeans1.labels_
print(silhouette_score(df_std1, labels= labels1))
new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans1'] = labels1


plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.5092340679384362

# %%
aa=4
b=['blue','red','green','pink']
c=['Kematian_anak', 'Harapan_hidup']
kmeans1 = KMeans(n_clusters = aa, random_state=31).fit(df_std2)
labels1 = kmeans1.labels_
print(silhouette_score(df_std2, labels= labels1))

new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans2'] = labels1


plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.47307179521909687

# %%
aa=4
b=['blue','red','green','pink']
c=['Kematian_anak', 'Pendapatan']
kmeans1 = KMeans(n_clusters = aa, random_state=31).fit(df_std3)
labels1 = kmeans1.labels_
print(silhouette_score(df_std3, labels= labels1))
new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans3'] = labels1
new_df

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.5365763130062863

# %%
aa=4
b=['blue','red','green','pink']
c=['Ekspor', 'Impor']
kmeans1 = KMeans(n_clusters = aa, random_state=30).fit(df_std4)
labels1 = kmeans1.labels_
print(silhouette_score(df_std4, labels= labels1))
new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans4'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green')

plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.38382206444289135

# %%
aa=4
b=['blue','red','green','pink']
c=['Ekspor','Pendapatan']
kmeans1 = KMeans(n_clusters = aa, random_state=48).fit(df_std5)
labels1 = kmeans1.labels_
print(silhouette_score(df_std5, labels= labels1))
new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans5'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.434431396905651

# %%
aa=4
b=['blue','red','green','pink']
c=['Pendapatan','Jumlah_fertiliti']
kmeans1 = KMeans(n_clusters = aa, random_state=49).fit(df_std6)
labels1 = kmeans1.labels_
print(silhouette_score(df_std6, labels= labels1))

new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans6'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.5208635140250013

# %%
aa=4
b=['blue','red','green','pink']
c=['Pendapatan','Harapan_hidup']
kmeans1 = KMeans(n_clusters = aa, random_state=42).fit(df_std7)
labels1 = kmeans1.labels_
print(silhouette_score(df_std7, labels= labels1))

new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans7'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], s=100, edgecolors='green', label=str(i))
plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])
plt.show()
# Out:
# 0.5269421681815323

# %%
aa=4
b=['blue','red','green','pink']
c=['Pendapatan','GDPperkapita']
kmeans1 = KMeans(n_clusters = aa, random_state=42).fit(df_std8)
labels1 = kmeans1.labels_
print(silhouette_score(df_std8, labels= labels1))

new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans8'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], label=str(i), s=100, edgecolors='green')

plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])

plt.show()
# Out:
# 0.6139089213550839

# %%
aa=4
b=['blue','red','green','pink']
c=['Jumlah_fertiliti','Harapan_hidup']
kmeans1 = KMeans(n_clusters = aa, random_state=31).fit(df_std9)
labels1 = kmeans1.labels_
print(silhouette_score(df_std9, labels= labels1))

new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans9'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], label=str(i), s=100, edgecolors='green')

plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])

plt.show()
# Out:
# 0.46490787811887385

# %%
aa=4
b=['blue','red','green','pink']
c=['GDPperkapita','Harapan_hidup']
kmeans1 = KMeans(n_clusters = aa, random_state=42).fit(df_std10)
labels1 = kmeans1.labels_
print(silhouette_score(df_std10, labels= labels1))
new_df = pd.DataFrame(data=df2, columns=[c[0],c[1]])
new_df['kmeans'] = labels1
df2['kmeans10'] = labels1

plt.figure(figsize=(12,8))
for i in range (aa):
    plt.scatter(new_df[c[0]][new_df.kmeans==i], new_df[c[1]][new_df.kmeans==i], c=b[i], label=str(i), s=100, edgecolors='green')

plt.legend()
plt.xlabel(c[0])
plt.ylabel(c[1])
plt.title(c[0]+' VS '+c[1])

plt.show()
# Out:
# 0.558656611929683

# %%
display(df2)
df2['kmeans10'] = labels1
display(df2)
# Out:
#      Kematian_anak  Ekspor  Impor  Pendapatan  Harapan_hidup  \
# 0             90.2    10.0   44.9        1610           56.2
# 1             16.6    28.0   48.6        9930           76.3
# 2             27.3    38.4   31.4       12900           76.5
# 3            119.0    62.3   42.9        5900           60.1
# 4             10.3    45.5   58.9       19100           76.8
# ..             ...     ...    ...         ...            ...
# 162           29.2    46.6   52.7        2950           63.0
# 163           17.1    28.5   17.6       16500           75.4
# 164           23.3    72.0   80.2        4490           73.1
# 165           56.3    30.0   34.4        4480           67.5
# 166           83.1    37.0   30.9        3280           52.0
#
#      Jumlah_fertiliti  GDPperkapita  kmeans1  kmeans2  kmeans3  kmeans4  \
# 0                5.82           553        3        3        0        0
# 1                1.65          4090        2        2        1        1
# ...

# %%
df3=df2.drop(columns=['Kematian_anak','Ekspor','Impor','Pendapatan','Harapan_hidup','Jumlah_fertiliti','GDPperkapita'])
df3
# Out:
#      kmeans1  kmeans2  kmeans3  kmeans4  kmeans5  kmeans6  kmeans7  kmeans8  \
# 0          3        3        0        0        0        0        0        0
# 1          2        2        1        1        0        3        1        0
# 2          1        2        1        0        0        3        1        0
# 3          0        0        0        1        3        0        0        0
# 4          2        2        1        1        3        3        1        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 162        1        1        1        1        3        3        0        0
# 163        1        2        1        0        0        3        1        1
# 164        2        1        1        3        3        3        1        0
# 165        3        1        1        0        0        0        1        0
# 166        3        0        0        0        0        0        0        0
#
#      kmeans9  kmeans10
# 0          2         0
# ...

# %%
#df4 = df3.eval('R = kmeans1 + kmeans2 + kmeans3 + kmeans4 + kmeans5 + kmeans6 + kmeans7 + kmeans8 + kmeans9 + kmeans10')
df4 = df3.eval('R = 0')
for i in df3.index:
    for j in df3 :
        if df3.loc[i,j] ==0:
           df4['R'].loc[i] += 1
#df4 = df4.drop(columns=['kmeans1','kmeans2','kmeans3','kmeans4','kmeans5','kmeans6','kmeans7','kmeans8','kmeans9','kmeans10'])
df5=df4.sort_values(by=['R'],ascending=False)[:10]
display(df4)
display(df5)
# Out:
#      kmeans1  kmeans2  kmeans3  kmeans4  kmeans5  kmeans6  kmeans7  kmeans8  \
# 0          3        3        0        0        0        0        0        0
# 1          2        2        1        1        0        3        1        0
# 2          1        2        1        0        0        3        1        0
# 3          0        0        0        1        3        0        0        0
# 4          2        2        1        1        3        3        1        1
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 162        1        1        1        1        3        3        0        0
# 163        1        2        1        0        0        3        1        1
# 164        2        1        1        3        3        3        1        0
# 165        3        1        1        0        0        0        1        0
# 166        3        0        0        0        0        0        0        0
#
#      kmeans9  kmeans10  R
# 0          2         0  7
# ...

# %%
df7=pd.DataFrame(columns=['Negara'])
for i in df5.index:
    df7.loc[i]=df.loc[i]

df7.reset_index(drop=True)
# Out:
#                      Negara
# 0  Central African Republic
# 1                  Cameroon
# 2              Burkina Faso
# 3              Sierra Leone
# 4             Guinea-Bissau
# 5                   Nigeria
# 6                     Benin
# 7                      Mali
# 8                   Burundi
# 9                      Chad
